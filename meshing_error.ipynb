# %%
# %load_ext autoreload
# %autoreload 2
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %%
import sectionproperties.pre.library.standard_sections as sections
from sectionproperties.pre.pre import Material
from sectionproperties.pre.geometry import CompoundGeometry
from sectionproperties.analysis.section import Section

mat_1 = Material("Material 1", 200e3, 0.3, 300, 1000, "yellow")
mat_2 = Material("Material 2", 72e3, 0.25, 100, 1000, "purple")

s1 = sections.rectangular_section(1,1)
s2 = sections.rectangular_section(0.5,0.5).shift_section(1,0.25)
s1.material = mat_1
s2.material = mat_2
geometry_fixed = CompoundGeometry([(s1 - s2), s2])
geometry_fixed.create_mesh([0.5])
sec = Section(geometry_fixed)

# %%
sec.plot_mesh()
# Out:
# (<Figure size 750x500 with 1 Axes>,
#  <AxesSubplot:title={'center':'Finite Element Mesh'}>)
